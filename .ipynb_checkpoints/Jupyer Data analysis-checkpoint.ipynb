# %%
import pandas as pd
from config import *
from help_functions import *
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/noa/opt/anaconda3/lib/python3.8/site-packages/ete3-3.1.2-py3.7.egg/ete3/evol/parser/codemlparser.py:221: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /Users/noa/opt/anaconda3/lib/python3.8/site-packages/ete3-3.1.2-py3.7.egg/ete3/evol/parser/codemlparser.py:221: SyntaxWarning: "is" with a literal. Did you mean "=="?

# %%
def get_all_results_df(data, n_trees_grid, n_iter, tree_type = None, run_name = None):
    if tree_type:
        data = data[data["tree_type"]==tree_type]
    if run_name:
        data = data[data["run_name"] == run_name]
    all_results_df = pd.DataFrame()
    for i in range(n_iter):
        print(i)
        for n_trees in n_trees_grid:
            grouped_data = data.groupby(by=["msa_name", "tree_type","run_name"]).sample(n=n_trees,random_state = i
                                                                                               ).groupby(
                by=["msa_name","tree_type","run_name"]).agg({"delta_ll_from_curr_starting_tree_best_topology": 'min'}).reset_index()
        grouped_data["msa_ind"] = grouped_data.index
        grouped_data["iteration"] = i
        if all_results_df.empty:
            all_results_df = grouped_data.copy()
        else:
            all_results_df = pd.concat([all_results_df, grouped_data])
    all_results_df = all_results_df.reset_index()
    return all_results_df

def pivot_results_df(all_results_df):
    all_results_df_melted = (all_results_df.melt(id_vars=["msa_ind","iteration","index","run_name","tree_type"],var_name = "n_trees", value_name = "best_ll_diff"))
    print(all_results_df_melted)
    all_results_df_melted = all_results_df_melted.groupby(["msa_ind","n_trees","index","run_name","tree_type"]).agg({'best_ll_diff': 'mean'}).reset_index()
    all_results_df_melted["msa_name"] =  all_results_df_melted["msa_ind"].astype('category')
    return all_results_df_melted

# %%
    overall_data_path = "/Users/noa/Workspace/raxml_deep_learning_results/single_gene_MSAs/full_raxml_data.tsv"
    data = pd.read_csv(overall_data_path, sep=CSV_SEP)
    tree_type = None
    n_iter=2
    n_trees_grid = list(range(1,5))
    run_name=None
    if tree_type:
        name = f'only_{tree_type}_{run_name}'
    else:
        name = f"both_parsimony_and_random_{run_name}"

    data["is_best_tree"] = data["rf_from_overall_msa_best_topology"] == 0
    all_results_df = get_all_results_df(data, n_trees_grid, n_iter = n_iter, tree_type = tree_type, run_name=run_name)
# Out:
# 0
# 1

# %%
all_results_df.head(20)
# Out:
#     index                    msa_name  tree_type   run_name  \
# 0       0  _BoroA6_OG107_gene75.fasta  parsimony    default
# 1       1  _BoroA6_OG107_gene75.fasta  parsimony   params_0
# 2       2  _BoroA6_OG107_gene75.fasta  parsimony   params_1
# 3       3  _BoroA6_OG107_gene75.fasta  parsimony  params_10
# 4       4  _BoroA6_OG107_gene75.fasta  parsimony  params_11
# 5       5  _BoroA6_OG107_gene75.fasta  parsimony  params_12
# 6       6  _BoroA6_OG107_gene75.fasta  parsimony  params_13
# 7       7  _BoroA6_OG107_gene75.fasta  parsimony  params_14
# 8       8  _BoroA6_OG107_gene75.fasta  parsimony  params_15
# 9       9  _BoroA6_OG107_gene75.fasta  parsimony  params_16
# 10     10  _BoroA6_OG107_gene75.fasta  parsimony  params_17
# 11     11  _BoroA6_OG107_gene75.fasta  parsimony  params_18
# 12     12  _BoroA6_OG107_gene75.fasta  parsimony  params_19
# 13     13  _BoroA6_OG107_gene75.fasta  parsimony   params_2
# 14     14  _BoroA6_OG107_gene75.fasta  parsimony  params_20
# 15     15  _BoroA6_OG107_gene75.fasta  parsimony  params_21
# 16     16  _BoroA6_OG107_gene75.fasta  parsimony  params_22
# 17     17  _BoroA6_OG107_gene75.fasta  parsimony  params_23
# 18     18  _BoroA6_OG107_gene75.fasta  parsimony  params_24
# 19     19  _BoroA6_OG107_gene75.fasta  parsimony   params_3
#
#     delta_ll_from_curr_starting_tree_best_topology  msa_ind  iteration
# 0                                         0.000000        0          0
# 1                                         9.928887        1          0
# 2                                         0.022527        2          0
# 3                                         0.000000        3          0
# 4                                         0.000000        4          0
# 5                                         0.000000        5          0
# 6                                         0.000000        6          0
# 7                                         0.000000        7          0
# 8                                         0.000000        8          0
# 9                                         0.000000        9          0
# 10                                        0.000000       10          0
# 11                                        0.000000       11          0
# 12                                        0.000000       12          0
# 13                                        0.022571       13          0
# 14                                        0.000000       14          0
# 15                                        0.000000       15          0
# 16                                        0.000000       16          0
# 17                                        0.000000       17          0
# 18                                        0.000000       18          0
# 19                                        0.022571       19          0

# %%
    all_results_df_melted = (all_results_df.melt(id_vars=["msa_name","msa_ind","iteration","run_name","tree_type","index"],var_name = "n_trees", value_name = "best_ll_diff"))
    all_results_df_melted = all_results_df_melted.groupby(["msa_name","msa_ind","n_trees","run_name","tree_type"]).agg({'best_ll_diff': 'mean'}).reset_index()
    all_results_df_melted["msa_ind_name"] =  all_results_df_melted["msa_ind"].astype('category')

# %%
    all_results_df_melted.head(10)
# Out:
#                      msa_name  msa_ind  \
# 0  _BoroA6_OG107_gene75.fasta        0
# 1  _BoroA6_OG107_gene75.fasta        1
# 2  _BoroA6_OG107_gene75.fasta        2
# 3  _BoroA6_OG107_gene75.fasta        3
# 4  _BoroA6_OG107_gene75.fasta        4
# 5  _BoroA6_OG107_gene75.fasta        5
# 6  _BoroA6_OG107_gene75.fasta        6
# 7  _BoroA6_OG107_gene75.fasta        7
# 8  _BoroA6_OG107_gene75.fasta        8
# 9  _BoroA6_OG107_gene75.fasta        9
#
#                                           n_trees   run_name  tree_type  \
# 0  delta_ll_from_curr_starting_tree_best_topology    default  parsimony
# 1  delta_ll_from_curr_starting_tree_best_topology   params_0  parsimony
# 2  delta_ll_from_curr_starting_tree_best_topology   params_1  parsimony
# 3  delta_ll_from_curr_starting_tree_best_topology  params_10  parsimony
# 4  delta_ll_from_curr_starting_tree_best_topology  params_11  parsimony
# 5  delta_ll_from_curr_starting_tree_best_topology  params_12  parsimony
# 6  delta_ll_from_curr_starting_tree_best_topology  params_13  parsimony
# 7  delta_ll_from_curr_starting_tree_best_topology  params_14  parsimony
# 8  delta_ll_from_curr_starting_tree_best_topology  params_15  parsimony
# 9  delta_ll_from_curr_starting_tree_best_topology  params_16  parsimony
#
#    best_ll_diff msa_ind_name
# 0      0.000000            0
# 1      5.266305            1
# 2      0.022527            2
# 3      0.000000            3
# 4      0.000000            4
# 5      0.000000            5
# 6      0.000000            6
# 7      0.000000            7
# 8      0.000000            8
# 9      0.000000            9

# %%
    g = sns.FacetGrid(all_results_df_melted, col="run_name", row ="tree_type", hue="msa_ind_name")
    name= "test"
    g.map(sns.lineplot, "best_ll_diff", "n_trees",legend = False)
    plt.savefig(f'line_plot_test.png')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-aed6c46bb9f5> in <module>
#       1 g = sns.FacetGrid(all_results_df_melted, col="run_name", row ="tree_type", hue="msa_ind_name")
#       2 name= "test"
# ----> 3 g.map(sns.lineplot, "best_ll_diff", "n_trees",legend = False)
#       4 plt.savefig(f'line_plot_test.png')
#       5 plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     651
#     652         # Iterate over the data subsets
# --> 653         for (row_i, col_j, hue_k), data_ijk in self.facet_data():
#     654
#     655             # If this subset is null, move on
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py in facet_data(self)
#     603                                                     enumerate(col_masks),
#     604                                                     enumerate(hue_masks)):
# --> 605             data_ijk = data[row & col & hue & self._not_na]
#     606             yield (i, j, k), data_ijk
#     607
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2891         # Do we have a (boolean) 1d indexer?
#    2892         if com.is_bool_indexer(key):
# -> 2893             return self._getitem_bool_array(key)
#    2894
#    2895         # We are left with two options: a single key, and a collection of keys,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2945         key = check_bool_indexer(self.index, key)
#    2946         indexer = key.nonzero()[0]
# -> 2947         return self._take_with_is_copy(indexer, axis=0)
#    2948
#    2949     def _getitem_multilevel(self, key):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis)
#    3361         See the docstring of `take` for full explanation of the parameters.
#    3362         """
# -> 3363         result = self.take(indices=indices, axis=axis)
#    3364         # Maybe set copy if we didn't actually change the index.
#    3365         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3348         self._consolidate_inplace()
#    3349
# -> 3350         new_data = self._mgr.take(
#    3351             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3352         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1445
#    1446         new_labels = self.axes[axis].take(indexer)
# -> 1447         return self.reindex_indexer(
#    1448             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1449         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate)
#    1282             new_blocks = self._slice_take_blocks_ax0(indexer, fill_value=fill_value)
#    1283         else:
# -> 1284             new_blocks = [
#    1285                 blk.take_nd(
#    1286                     indexer,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1283         else:
#    1284             new_blocks = [
# -> 1285                 blk.take_nd(
#    1286                     indexer,
#    1287                     axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1722         # but are passed the axis depending on the calling routing
#    1723         # if its REALLY axis 0, then this will be a reindex and not a take
# -> 1724         new_values = self.values.take(indexer, fill_value=fill_value, allow_fill=True)
#    1725
#    1726         # Called from three places in managers, all of which satisfy
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/categorical.py in take(self, indexer, allow_fill, fill_value)
#    1808         will raise a ``ValueError``.
#    1809         """
# -> 1810         return NDArrayBackedExtensionArray.take(
#    1811             self, indexer, allow_fill=allow_fill, fill_value=fill_value
#    1812         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/_mixins.py in take(self, indices, allow_fill, fill_value)
#      40             fill_value = self._validate_fill_value(fill_value)
#      41
# ---> 42         new_data = take(
#      43             self._ndarray, indices, allow_fill=allow_fill, fill_value=fill_value,
#      44         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/algorithms.py in take(arr, indices, axis, allow_fill, fill_value)
#    1605         # Pandas style, -1 means NA
#    1606         validate_indices(indices, arr.shape[axis])
# -> 1607         result = take_1d(
#    1608             arr, indices, axis=axis, allow_fill=True, fill_value=fill_value
#    1609         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1653         return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#    1654
# -> 1655     arr = extract_array(arr)
#    1656     arr = np.asarray(arr)
#    1657
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/construction.py in extract_array(obj, extract_numpy)
#     379     array([1, 2, 3])
#     380     """
# --> 381     if isinstance(obj, (ABCIndexClass, ABCSeries)):
#     382         obj = obj.array
#     383
#
# KeyboardInterrupt:

# %%
    sns.boxplot(data=all_results_df_melted  , y="best_ll_diff", x="n_trees")
    plt.savefig(f'{name}_bar_plot.png')
    plt.tight_layout()
    plt.show()

# %%
# Out:
# 'delta_ll_from_curr_starting_tree_best_topology'
